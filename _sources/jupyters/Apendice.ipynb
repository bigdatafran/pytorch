# %% [markdown]
# # Apéndice.
#
#
# ## Enlaces interesantes.
#
# ### Cursos
#
# * <a href="https://theaisummer.com/learn-pytorch/" target="_blank">Entendiendo Pytorch </a>
#
# ### Pytorch
#
# * <a href="https://machinelearningmastery.com/save-and-load-your-pytorch-models/?utm_source=drip&utm_medium=email&utm_campaign=Using+activation+functions+in+deep+learning+models&utm_content=Using+activation+functions+in+deep+learning+models" target="_blank"> Salvando y cargando modelos </a>
#
# * <a href="https://machinelearningmastery.com/calculating-derivatives-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Text+Generation+with+LSTM+in+PyTorch&utm_content=Text+Generation+with+LSTM+in+PyTorch" target="_blank">Calculando derivadas en Pytorch </a>
#
# * <a heref="https://machinelearningmastery.com/using-activation-functions-in-deep-learning-models/?utm_source=drip&utm_medium=email&utm_campaign=Using+activation+functions+in+deep+learning+models&utm_content=Using+activation+functions+in+deep+learning+models" target="_blank">  Usando funciones de activación </a>
#
# * <a href="https://machinelearningmastery.com/loss-functions-in-pytorch-models/?utm_source=drip&utm_medium=email&utm_campaign=Using+activation+functions+in+deep+learning+models&utm_content=Using+activation+functions+in+deep+learning+models" target="_blank"> Funciones de pérdida en Pytorch </a>
#
# * <a href="https://machinelearningmastery.com/how-to-evaluate-the-performance-of-pytorch-models/?utm_source=drip&utm_medium=email&utm_campaign=Building+a+multiclass+classification+model+in+PyTorch&utm_content=Building+a+multiclass+classification+model+in+PyTorch" target="_blank"> Evaluando el ajuste con Pytorch </a>
#
# *  <a href="https://machinelearningmastery.com/building-a-multiclass-classification-model-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Building+a+multiclass+classification+model+in+PyTorch&utm_content=Building+a+multiclass+classification+model+in+PyTorch" target="_blank"> Haciendo una clasificación multiclase en Pytorch </a>
#
# * <a href="https://machinelearningmastery.com/building-a-softmax-classifier-for-images-in-pytorch/" target='_blank'>Haciendo una clasificación softmax para imágenes </a>
#
# *  <a href="https://machinelearningmastery.com/building-a-binary-classification-model-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Building+a+multiclass+classification+model+in+PyTorch&utm_content=Building+a+multiclass+classification+model+in+PyTorch" target="_blank"> Haciendo una clasificación binaria en Pytorch</a>
#
# * <a href="https://machinelearningmastery.com/building-multilayer-perceptron-models-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Develop+your+first+neural+network+with+PyTorch&utm_content=Develop+your+first+neural+network+with+PyTorch" target="_blank"> Building Multilayer Perceptron Models in PyTorch </a>
#
# * <a href="https://machinelearningmastery.com/develop-your-first-neural-network-with-pytorch-step-by-step/?utm_source=drip&utm_medium=email&utm_campaign=Develop+your+first+neural+network+with+PyTorch&utm_content=Develop+your+first+neural+network+with+PyTorch" target="_blank"> Develop Your First Neural Network with PyTorch, Step-by-Step </a>
#
# *  <a href="https://machinelearningmastery.com/creating-a-training-loop-for-pytorch-models/?utm_source=drip&utm_medium=email&utm_campaign=Develop+your+first+neural+network+with+PyTorch&utm_content=Develop+your+first+neural+network+with+PyTorch" target="_blank"> Creating a Training Loop for PyTorch Models </a>
#
# * <a href="https://machinelearningmastery.com/manipulating-tensors-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Manipulating+tensors+in+PyTorch&utm_content=Manipulating+tensors+in+PyTorch" target="_blank"> Manipulando tensores </a>
#
# * <a href="https://machinelearningmastery.com/using-autograd-in-pytorch-to-solve-a-regression-problem/?utm_source=drip&utm_medium=email&utm_campaign=Manipulating+tensors+in+PyTorch&utm_content=Manipulating+tensors+in+PyTorch" target="_blank"> Using Autograd in PyTorch to Solve a Regression Problem </a>
#
# * <a href="https://machinelearningmastery.com/building-multilayer-perceptron-models-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Manipulating+tensors+in+PyTorch&utm_content=Manipulating+tensors+in+PyTorch" target="_blank">  Building Multilayer Perceptron
# Models in PyTorch </a>
#
# * <a href ="https://machinelearningmastery.com/training-a-pytorch-model-with-dataloader-and-dataset/?utm_source=drip&utm_medium=email&utm_campaign=Training+a+PyTorch+model+with+DataLoader+and+dataset&utm_content=Training+a+PyTorch+model+with+DataLoader+and+dataset" target="_blank">Entrenando un modelo Pytorch con DataLoader y Dataset </a>
#
# * <a href="https://machinelearningmastery.com/using-learning-rate-schedule-in-pytorch-training/?utm_source=drip&utm_medium=email&utm_campaign=Training+a+PyTorch+model+with+DataLoader+and+dataset&utm_content=Training+a+PyTorch+model+with+DataLoader+and+dataset" target="__blank"> Usando Learning Rate en Pytorch </a>
#
# * <a href="https://machinelearningmastery.com/using-dropout-regularization-in-pytorch-models/?utm_source=drip&utm_medium=email&utm_campaign=Training+a+PyTorch+model+with+DataLoader+and+dataset&utm_content=Training+a+PyTorch+model+with+DataLoader+and+dataset" target="_blank"> Utilizando la regularización Dropout en Pytorch </a>
#
# * <a href="https://machinelearningmastery.com/visualizing-a-pytorch-model/?utm_source=drip&utm_medium=email&utm_campaign=Visualizing+a+PyTorch+model&utm_content=Visualizing+a+PyTorch+model" target="_blank"> Visualizando un modelo de Pytorch </a>
#
# * <a href="https://machinelearningmastery.com/managing-a-pytorch-training-process-with-checkpoints-and-early-stopping/?utm_source=drip&utm_medium=email&utm_campaign=Visualizing+a+PyTorch+model&utm_content=Visualizing+a+PyTorch+model" target="_blank"> Managing a PyTorch Training Process with Checkpoints and Early Stopping </a>
#
# * <a href="https://machinelearningmastery.com/understand-model-behavior-during-training-by-visualizing-metrics/?utm_source=drip&utm_medium=email&utm_campaign=Visualizing+a+PyTorch+model&utm_content=Visualizing+a+PyTorch+model" targe="_blank"> Understand Model python Behavior During Training by Visualizing Metrics </a>
#
# * <a href="https://machinelearningmastery.com/building-a-convolutional-neural-network-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Handwritten+digit+recognition+with+LeNet5+model+in+PyTorch&utm_content=Handwritten+digit+recognition+with+LeNet5+model+in+PyTorch"> Creando una red convolucional en Pytorch </a>
#
#
# * <a href="https://machinelearningmastery.com/handwritten-digit-recognition-with-lenet5-model-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Handwritten+digit+recognition+with+LeNet5+model+in+PyTorch&utm_content=Handwritten+digit+recognition+with+LeNet5+model+in+PyTorch"> Handwritten Digit Recognition with LeNet5 Model in PyTorch </a>
#
# * <a href="https://machinelearningmastery.com/lstm-for-time-series-prediction-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Handwritten+digit+recognition+with+LeNet5+model+in+PyTorch&utm_content=Handwritten+digit+recognition+with+LeNet5+model+in+PyTorch"> LSTM para predicción de series temporales en Pytorch</a>
#
# * <a href="https://machinelearningmastery.com/text-generation-with-lstm-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Text+Generation+with+LSTM+in+PyTorch&utm_content=Text+Generation+with+LSTM+in+PyTorch" target="_blank"> Generación de textos con LSTM y Pytorch</a>
#
# * <a href="https://machinelearningmastery.com/pytorch-tutorial-develop-deep-learning-models/?utm_source=drip&utm_medium=email&utm_campaign=Text+Generation+with+LSTM+in+PyTorch&utm_content=Text+Generation+with+LSTM+in+PyTorch" target="_blank">PyTorch Tutorial: How to Develop Deep Learning Models with Python </a>
#
# * <a href="https://machinelearningmastery.com/building-an-image-classifier-with-a-single-layer-neural-network-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Building+an+image+classifier+with+a+single-layer+neural+network+in+PyTorch&utm_content=Building+an+image+classifier+with+a+single-layer+neural+network+in+PyTorch" target='_blank'>Creando un clasificador de imágenes con Pytorch </a>
#
# * <a href="https://machinelearningmastery.com/training-logistic-regression-with-cross-entropy-loss-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Building+an+image+classifier+with+a+single-layer+neural+network+in+PyTorch&utm_content=Building+an+image+classifier+with+a+single-layer+neural+network+in+PyTorch" target="_blank">Entrenando un modelo de regresión logística con la función de pérdida de Cross-Entropía en PyTorch </a>
#
# * <a href="https://machinelearningmastery.com/building-a-logistic-regression-classifier-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Building+an+image+classifier+with+a+single-layer+neural+network+in+PyTorch&utm_content=Building+an+image+classifier+with+a+single-layer+neural+network+in+PyTorch" target="_blank">Creando un modelo de regresión logística en PyTorch </a>
#
# ### Convoluciones.
#
# *  <a href="https://setosa.io/ev/image-kernels/" target="_blan">  https://setosa.io/ev/image-kernels/ </a>
#
# * https://www.youtube.com/watch?v=ns2L2T6wvAY (video)
#
# ### Dataset's
#
# * <a href="https://huggingface.co/docs/datasets/index" target="_blank"> HuggingFace’s Dataset</a>
#
# * <a href="https://github.com/RaRe-Technologies/gensim-data" taget="_blak"> Gensim-dats's repository. Modelos Word2Vec preentrenados </a>
#
#
# ### Incremento de palabras:
#
# * <a href="https://github.com/QData/TextAttack" target="_blank"> TextAttack </a>
#
# ### Languaje Modeling
#
# <a href="https://lena-voita.github.io/nlp_course/language_modeling.html#main_content" target="_blank">Language Modeling </a>
#
# ### Hugging Face.
#
# * https://www.youtube.com/watch?v=4yhYu1emS3M
#
# * https://juansensio.com/blog/105_hf_intro
#
# ### blog's
#
# * https://juansensio.com/
#
# ### NLP en español
#
# * <a href="https://somosnlp.org/core-team">Somos NLP</a>
#
# * <a href="https://www.youtube.com/c/somosnlp">somos NLP. Youtve </a>
#
# ### Regresión lineal.
#
# * <a href="https://machinelearningmastery.com/making-predictions-with-multilinear-regression-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Making+predictions+with+multilinear+regression+in+PyTorch&utm_content=Making+predictions+with+multilinear+regression+in+PyTorch" target="_blank"> Haciendo predicciones </a>
#
# * <a href="https://machinelearningmastery.com/training-a-single-output-multilinear-regression-model-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Making+predictions+with+multilinear+regression+in+PyTorch&utm_content=Making+predictions+with+multilinear+regression+in+PyTorch" target="_blanK">Entrenando el modelo de regresión multilineal en pyTorch</a>

# %% [markdown]
# a_
